# %%
import fnn.functions as func

# %%
noise = func.get_noise(100000, 2).data.numpy()
noise_list = []
for i in noise:
    for j in i:
        noise_list.append(j)

# %%
import seaborn as sns
sns.histplot(noise_list)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
a = func.get_noise_uniform(100000, 2).data.numpy()
a_list = []
for i in a:
    for j in i:
        a_list.append(j)
sns.histplot(a_list)
# Out:
# <AxesSubplot:ylabel='Count'>
